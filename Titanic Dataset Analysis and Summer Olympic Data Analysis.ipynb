# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:\\Users\\Rohith varma\\Downloads\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\titanic.csv')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
#so inorder to display max rows and min rows 

pd.options.display.max_rows=10

# %%
pd.options.display.min_rows=20

# %%
data
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
#first data inspection 
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.describe(include='O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#rounding whole dataset to 0.0
round(data,0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
min(data)
# Out:
# 'age'

# %%
data.min()
# Out:
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare             0
# dtype: object

# %%
#when you select one column its type will be pandas series when you select more than one column it will be  pandas dataframe
type(data['age'])
# Out:
# pandas.core.series.Series

# %%
data.age.count() #gives count of non null values
# Out:
# 714

# %%
data.age.size #gives count of all values
# Out:
# 891

# %%
data.age.value_counts(normalize=True) #to calculate normalize value= 30/age.count()
# Out:
# 24.00    0.042017
# 22.00    0.037815
# 18.00    0.036415
# 19.00    0.035014
# 30.00    0.035014
#            ...
# 55.50    0.001401
# 70.50    0.001401
# 66.00    0.001401
# 23.50    0.001401
# 0.42     0.001401
# Name: age, Length: 88, dtype: float64

# %%
# if you want to include null value dropna=True 
data.age.value_counts(dropna=False,normalize=True)
# Out:
# NaN      0.198653
# 24.00    0.033670
# 22.00    0.030303
# 18.00    0.029181
# 28.00    0.028058
#            ...
# 36.50    0.001122
# 55.50    0.001122
# 66.00    0.001122
# 23.50    0.001122
# 0.42     0.001122
# Name: age, Length: 89, dtype: float64

# %%
#bin divides the range of those column to mention how many ranges 

data.age.value_counts(sort=True,dropna=True,ascending=False,normalize=False,bins=10)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: age, dtype: int64

# %%
l=data['fare'].value_counts().head(1)

# %%
l.index
# Out:
# Float64Index([8.05], dtype='float64')

# %%
fare = data.fare.copy() 
fare.sort_values(ascending=False)
# Out:
# 679    512.3292
# 258    512.3292
# 737    512.3292
# 341    263.0000
# 438    263.0000
#          ...
# 277      0.0000
# 633      0.0000
# 302      0.0000
# 597      0.0000
# 271      0.0000
# Name: fare, Length: 891, dtype: float64

# %%
#nlargest() and nsmallest()
age=data.age.copy()

# %%
age.nlargest().index[0]
# Out:
# 630

# %%
age.sort_values(ascending=True).iloc[:3]
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# Name: age, dtype: float64

# %%
#age.nlargest().index[0] so, nlargest returns the 5 max rows and their first value at 0
#idxmax() and idxmin() 
age.idxmax()
# Out:
# 630

# %%
#pandas series 
sales=pd.Series([10,20,6,7,None,5,8,0],index=['Mon','Tue','Wed','Thu','Fri','Sat','Sun','Mon'])
sales
# Out:
# Mon    10.0
# Tue    20.0
# Wed     6.0
# Thu     7.0
# Fri     NaN
# Sat     5.0
# Sun     8.0
# Mon     0.0
# dtype: float64

# %%
sales['Sun']=23

# %%
sales
# Out:
# Mon    10.0
# Tue    20.0
# Wed     6.0
# Thu     7.0
# Fri     NaN
# Sat     5.0
# Sun    23.0
# Mon     0.0
# dtype: float64

# %%
#we can also override using iloc 
sales.iloc[3]=30

# %%
sales
# Out:
# Mon    10.0
# Tue    20.0
# Wed     6.0
# Thu    30.0
# Fri     NaN
# Sat     5.0
# Sun    23.0
# Mon     0.0
# dtype: float64

# %%
#to convert to euro currency 
sales_EUR=(sales/1.1).round(2) 
sales_EUR
# Out:
# Mon     9.09
# Tue    18.18
# Wed     5.45
# Thu    27.27
# Fri      NaN
# Sat     4.55
# Sun    20.91
# Mon     0.00
# dtype: float64

# %%
sales*100
# Out:
# Mon    1000.0
# Tue    2000.0
# Wed     600.0
# Thu    3000.0
# Fri       NaN
# Sat     500.0
# Sun    2300.0
# Mon       0.0
# dtype: float64

# %%
data.age*100
# Out:
# 0      2200.0
# 1      3800.0
# 2      2600.0
# 3      3500.0
# 4      3500.0
#         ...
# 886    2700.0
# 887    1900.0
# 888       NaN
# 889    2600.0
# 890    3200.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# #changing column labels
# we can change using
# data.columns=["newcolumnname","Class","Sex".....]
# if you want to change the col index name data.column.name="passe_charcater"
# or
# for row index
# data.index.name=""

# %%
data.loc[data.sex=="male","fare"]
# Out:
# 0       7.2500
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
#         ...
# 883    10.5000
# 884     7.0500
# 886    13.0000
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 577, dtype: float64

# %%
#filtering by and
mask1=data.sex=='male'
mask1.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
mask2=data.age>14 
mask2.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: age, dtype: bool

# %%
(mask1 & mask2).head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
male_surv=data.loc[mask1 & mask2,['survived','pclass','sex','age']] 

male_surv.head(20)
# Out:
#     survived  pclass   sex   age
# 0          0       3  male  22.0
# 4          0       3  male  35.0
# 6          0       1  male  54.0
# 12         0       3  male  20.0
# 13         0       3  male  39.0
# ..       ...     ...   ...   ...
# 54         0       1  male  65.0
# 57         0       3  male  28.5
# 60         0       3  male  22.0
# 62         0       1  male  45.0
# 67         0       3  male  19.0
#
# [20 rows x 4 columns]

# %%
male_surv.describe()
# Out:
#          survived      pclass         age
# count  414.000000  414.000000  414.000000
# mean     0.173913    2.309179   33.129227
# std      0.379493    0.829868   12.922177
# min      0.000000    1.000000   15.000000
# 25%      0.000000    2.000000   23.000000
# 50%      0.000000    3.000000   30.000000
# 75%      0.000000    3.000000   40.000000
# max      1.000000    3.000000   80.000000

# %%
#we use or to check whether being female or child has probability to survive the disaster 
mask1=data.sex=='female'

# %%
mask2=data.age<14

# %%
(mask1 | mask2).head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
data.loc[mask1 | mask2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [351 rows x 9 columns]

# %%
#any() and all()
(data.sex =='male').any()
# Out:
# True

# %%
(data.sex=='male').all()
# Out:
# False

# %%
(data.age==80).any()
# Out:
# True

# %%
#Adding new columns to a dataframe

# %%
data['zeroes']=0

# %%
data.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  zeroes
# 0         0       3    male  22.0      1      0   7.2500        S  NaN       0
# 1         1       1  female  38.0      1      0  71.2833        C    C       0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN       0
# 3         1       1  female  35.0      1      0  53.1000        S    C       0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN       0

# %%
#To calculate DoB(year). titanic happened in 1912-age
data['YoB']=1912-data.age

# %%
data.drop(columns='zeroes',inplace=True)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck     YoB
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  1890.0
# 1         1       1  female  38.0      1      0  71.2833        C    C  1874.0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  1886.0
# 3         1       1  female  35.0      1      0  53.1000        S    C  1877.0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  1877.0

# %%
#adding columns not at last but to insert at particular index 
relative=data.sibsp+data.parch

# %%
relative.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# dtype: int64

# %%
data.insert(loc=6,column="relative",value=relative)

# %%
data.drop(columns='relatives',inplace=True)

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  relative     fare embarked  \
# 0         0       3    male  22.0      1      0         1   7.2500        S
# 1         1       1  female  38.0      1      0         1  71.2833        C
# 2         1       3  female  26.0      0      0         0   7.9250        S
# 3         1       1  female  35.0      1      0         1  53.1000        S
# 4         0       3    male  35.0      0      0         0   8.0500        S
#
#   deck
# 0  NaN
# 1    C
# 2  NaN
# 3    C
# 4  NaN

# %%
df={'Car':['BMW','Honda','Ford'] ,'Job':['Pilot','Cook','Salesman']} 
i=['Mike','Steve','Andy']
k=pd.DataFrame(df) 
k.index=i
print(k)
# Out:
#          Car       Job
# Mike     BMW     Pilot
# Steve  Honda      Cook
# Andy    Ford  Salesman

# %%
k.reset_index(inplace=True)

# %%
k
# Out:
#    index    Car       Job
# 0   Mike    BMW     Pilot
# 1  Steve  Honda      Cook
# 2   Andy   Ford  Salesman

# %%
#adding new row to a data frame
k.loc[3, :]=['Neymer','Tesla','Lawyer']

# %%
k
# Out:
#     index    Car       Job
# 0    Mike    BMW     Pilot
# 1   Steve  Honda      Cook
# 2    Andy   Ford  Salesman
# 3  Neymer  Tesla    Lawyer

# %%
new_k=pd.DataFrame(
     data=[["Sahi","Mahindra","Coach"],["Inon","BMW","doctor"]], 
    columns=k.columns
)

# %%
k=k.append(new_k,ignore_index=True)

# %%
k
# Out:
#     index       Car       Job
# 0    Mike       BMW     Pilot
# 1   Steve     Honda      Cook
# 2    Andy      Ford  Salesman
# 3  Neymer     Tesla    Lawyer
# 4    Sahi  Mahindra     Coach
# 5    Inon       BMW    doctor

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
#lets say 1st row  has wrong values in survived,pclass and sex columns 
data.loc[0,'survived':'sex']=[1,1,'female']

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         1       1  female  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
#changing multiple values in multiple row 
data.replace(0,'zero')
# Out:
#     survived  pclass     sex   age sibsp parch     fare embarked deck
# 0          1       1  female  22.0     1  zero     7.25        S  NaN
# 1          1       1  female  38.0     1  zero  71.2833        C    C
# 2          1       3  female  26.0  zero  zero    7.925        S  NaN
# 3          1       1  female  35.0     1  zero     53.1        S    C
# 4       zero       3    male  35.0  zero  zero     8.05        S  NaN
# ..       ...     ...     ...   ...   ...   ...      ...      ...  ...
# 886     zero       2    male  27.0  zero  zero       13        S  NaN
# 887        1       1  female  19.0  zero  zero       30        S    B
# 888     zero       3  female   NaN     1     2    23.45        S  NaN
# 889        1       1    male  26.0  zero  zero       30        C    C
# 890     zero       3    male  32.0  zero  zero     7.75        Q  NaN
#
# [891 rows x 9 columns]

# %%
#chainde indexing 
#data.age[1]=41 
#but better practice is to use loc operator 
data.loc[1,'age']=41

# %%
#  _is_view can change the dataframe 
#  _is_copy wont change the dataframe 

df_baby=data[data.age<1]

# %%
df_baby._is_view
# Out:
# False

# %%
df_baby._is_copy() #making a copy
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           1       1  female  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
#dont want to change the dataframe 
high_eff = cars.loc[cars.mpg > 40].copy() 
#or 
#want to change the dataframe 
cars.loc[cars.mpg>40,"mpg"]=40

# %%
#sort values 
data.age.sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
data.sort_values(by='age')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
data.sort_values(by=['pclass','sex','age'],ascending=True,inplace=True)

# %%
data.head(20) 
#so here the index is changed when we want to set to normal 
data.sort_values(by="age").reset_index(drop=True)  
#or
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           1       3    male  0.42      0      1   8.5167        C  NaN
# 1           1       2    male  0.67      1      1  14.5000        S  NaN
# 2           1       3  female  0.75      2      1  19.2583        C  NaN
# 3           1       3  female  0.75      2      1  19.2583        C  NaN
# 4           1       2    male  0.83      1      1  18.7500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       3    male   NaN      0      0   8.0500        S  NaN
# 887         0       3    male   NaN      8      2  69.5500        S  NaN
# 888         0       3    male   NaN      0      0   7.2292        C  NaN
# 889         0       3    male   NaN      0      0   9.5000        S  NaN
# 890         0       3    male   NaN      0      0   7.8958        S  NaN
#
# [891 rows x 9 columns]

# %%
data.sort_values(by='age',ignore_index=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           1       3    male  0.42      0      1   8.5167        C  NaN
# 1           1       2    male  0.67      1      1  14.5000        S  NaN
# 2           1       3  female  0.75      2      1  19.2583        C  NaN
# 3           1       3  female  0.75      2      1  19.2583        C  NaN
# 4           1       2    male  0.83      1      1  18.7500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       3    male   NaN      0      0   8.0500        S  NaN
# 887         0       3    male   NaN      8      2  69.5500        S  NaN
# 888         0       3    male   NaN      0      0   7.2292        C  NaN
# 889         0       3    male   NaN      0      0   9.5000        S  NaN
# 890         0       3    male   NaN      0      0   7.8958        S  NaN
#
# [891 rows x 9 columns]

# %%
#ranking dataframe with rank
sales=pd.Series([12,13,14,15,16,24,0],index=["mon","tue",'wed','thu','fri','sat','sun'])

# %%
sales
# Out:
# mon    12
# tue    13
# wed    14
# thu    15
# fri    16
# sat    24
# sun     0
# dtype: int64

# %%
sales.sort_values(ascending=False)
# Out:
# sat    24
# fri    16
# thu    15
# wed    14
# tue    13
# mon    12
# sun     0
# dtype: int64

# %%
sales.rank(ascending=False,method="max").sort_values(ascending=True)
# Out:
# sat    1.0
# fri    2.0
# thu    3.0
# wed    4.0
# tue    5.0
# mon    6.0
# sun    7.0
# dtype: float64

# %%
data.nunique(axis=0,dropna=False) #by if you want to get for every column then then (axis=0) 
#and to get missing values in it
# Out:
# survived      2
# pclass        3
# sex           2
# age          89
# sibsp         7
# parch         7
# fare        248
# embarked      4
# deck          8
# dtype: int64

# %%
#nlargest for a colum 
data.nlargest(n=5,columns='fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 341         1       1  female  24.0      3      2  263.0000        S    C

# %%
#to get the index of the youngest passenger 
data.loc[data.age.idxmin()] #idxmin() get min index
# Out:
# survived         1
# pclass           3
# sex           male
# age           0.42
# sibsp            0
# parch            1
# fare        8.5167
# embarked         C
# deck           NaN
# Name: 803, dtype: object

# %%
data.count(axis=0)
# Out:
# survived    891
# pclass      891
# sex         891
# age         714
# sibsp       891
# parch       891
# fare        891
# embarked    889
# deck        203
# dtype: int64

# %%
data.mean(axis=0)
# Out:
# survived     0.384961
# pclass       2.306397
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
data.sum(axis=0)
# Out:
# survived                                                  343
# pclass                                                   2055
# sex         femalefemalefemalefemalefemalefemalefemalefema...
# age                                                   21205.2
# sibsp                                                     466
# parch                                                     340
# fare                                                  28693.9
# dtype: object

# %%
data.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 297         0       1  female   2.0      1      2  151.5500        S    C
# 435         1       1  female  14.0      1      2  120.0000        S    B
# 689         1       1  female  15.0      0      1  211.3375        S    B
# 329         1       1  female  16.0      0      1   57.9792        C    B
# 504         1       1  female  16.0      0      0   86.5000        S    B

# %%
data.fare.cumsum(axis=0)
# Out:
# 297      151.5500
# 435      271.5500
# 689      482.8875
# 329      540.8667
# 504      627.3667
#           ...
# 837    28599.7743
# 846    28669.3243
# 859    28676.5535
# 868    28686.0535
# 878    28693.9493
# Name: fare, Length: 891, dtype: float64

# %%
#correlation is relation between 2 variables values between -1 and 1 
#where - means one values goes up and other goes down 

data.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.339447 -0.078691 -0.034305  0.080492  0.256007
# pclass   -0.339447  1.000000 -0.367108  0.081838  0.019696 -0.547609
# age      -0.078691 -0.367108  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.034305  0.081838 -0.308247  1.000000  0.414838  0.159651
# parch     0.080492  0.019696 -0.189119  0.414838  1.000000  0.216225
# fare      0.256007 -0.547609  0.096067  0.159651  0.216225  1.000000

# %%
data.survived.corr(data.pclass)
# Out:
# -0.3394471431498746

# %%
data.mean()
# Out:
# survived     0.384961
# pclass       2.306397
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
#to combine those statistics we use agg() 
data.agg(["mean","std"])
# Out:
#       survived    pclass        age     sibsp     parch       fare
# mean  0.384961  2.306397  29.699118  0.523008  0.381594  32.204208
# std   0.486859  0.836897  14.526497  1.102743  0.806057  49.693429

# %%
#if you want more customization
data.agg({'survived':'mean','age':['min','max']})
# Out:
#       survived    age
# max        NaN  80.00
# mean  0.384961    NaN
# min        NaN   0.42

# %%
data.set_index(['pclass','sex'],inplace=True)

# %%
#sort index in a  multiple columns 

data.sort_index(ascending=[True,False],inplace=True)

# %%
data
# Out:
#                survived    age  sibsp  parch      fare embarked deck
# pclass sex
# 1      male           1   0.92      1      2  151.5500        S    C
#        male           1   4.00      0      2   81.8583        S    A
#        male           1  11.00      1      2  120.0000        S    B
#        male           1  17.00      0      2  110.8833        C    C
#        male           0  18.00      1      0  108.9000        C    C
# ...                 ...    ...    ...    ...       ...      ...  ...
# 3      female         1    NaN      0      0    7.7333        Q  NaN
#        female         1    NaN      0      0    7.7375        Q  NaN
#        female         0    NaN      8      2   69.5500        S  NaN
#        female         0    NaN      8      2   69.5500        S  NaN
#        female         0    NaN      1      2   23.4500        S  NaN
#
# [891 rows x 7 columns]

# %%
#we can swap the indexs 
data.swaplevel()
# Out:
#                survived    age  sibsp  parch      fare embarked deck
# sex    pclass
# male   1              1   0.92      1      2  151.5500        S    C
#        1              1   4.00      0      2   81.8583        S    A
#        1              1  11.00      1      2  120.0000        S    B
#        1              1  17.00      0      2  110.8833        C    C
#        1              0  18.00      1      0  108.9000        C    C
# ...                 ...    ...    ...    ...       ...      ...  ...
# female 3              1    NaN      0      0    7.7333        Q  NaN
#        3              1    NaN      0      0    7.7375        Q  NaN
#        3              0    NaN      8      2   69.5500        S  NaN
#        3              0    NaN      8      2   69.5500        S  NaN
#        3              0    NaN      1      2   23.4500        S  NaN
#
# [891 rows x 7 columns]

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      pclass     sex  survived    age  sibsp  parch      fare embarked deck
# 0         1    male         1   0.92      1      2  151.5500        S    C
# 1         1    male         1   4.00      0      2   81.8583        S    A
# 2         1    male         1  11.00      1      2  120.0000        S    B
# 3         1    male         1  17.00      0      2  110.8833        C    C
# 4         1    male         0  18.00      1      0  108.9000        C    C
# ..      ...     ...       ...    ...    ...    ...       ...      ...  ...
# 886       3  female         1    NaN      0      0    7.7333        Q  NaN
# 887       3  female         1    NaN      0      0    7.7375        Q  NaN
# 888       3  female         0    NaN      8      2   69.5500        S  NaN
# 889       3  female         0    NaN      8      2   69.5500        S  NaN
# 890       3  female         0    NaN      1      2   23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
data=data.set_index(['pclass','sex']).sort_index(ascending=True)

# %%
data
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         0   2.0      1      2  151.5500        S    C
#        female         1  14.0      1      2  120.0000        S    B
#        female         1  15.0      0      1  211.3375        S    B
#        female         1  16.0      0      1   57.9792        C    B
#        female         1  16.0      0      0   86.5000        S    B
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      male           0   NaN      0      0    8.0500        S  NaN
#        male           0   NaN      8      2   69.5500        S  NaN
#        male           0   NaN      0      0    7.2292        C  NaN
#        male           0   NaN      0      0    9.5000        S  NaN
#        male           0   NaN      0      0    7.8958        S  NaN
#
# [891 rows x 7 columns]

# %%
data.loc[1] 
#selecting only 1st class
# Out:
#         survived   age  sibsp  parch      fare embarked deck
# sex
# female         0   2.0      1      2  151.5500        S    C
# female         1  14.0      1      2  120.0000        S    B
# female         1  15.0      0      1  211.3375        S    B
# female         1  16.0      0      1   57.9792        C    B
# female         1  16.0      0      0   86.5000        S    B
# ...          ...   ...    ...    ...       ...      ...  ...
# male           1   NaN      0      0   30.0000        S    D
# male           0   NaN      0      0   39.6000        C  NaN
# male           0   NaN      0      0   30.6958        C  NaN
# male           0   NaN      0      0    0.0000        S    B
# male           1   NaN      0      0   29.7000        C    C
#
# [217 rows x 7 columns]

# %%
data.loc[1,'female'] #rowindex and column index
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         0   2.0      1      2  151.5500        S    C
#        female         1  14.0      1      2  120.0000        S    B
#        female         1  15.0      0      1  211.3375        S    B
#        female         1  16.0      0      1   57.9792        C    B
#        female         1  16.0      0      0   86.5000        S    B
# ...                 ...   ...    ...    ...       ...      ...  ...
#        female         1   NaN      1      0  133.6500        S  NaN
#        female         1   NaN      1      0   82.1708        C  NaN
#        female         1   NaN      1      0   51.8625        S    D
#        female         1   NaN      1      0   52.0000        S    C
#        female         1   NaN      1      0   89.1042        C    C
#
# [95 rows x 7 columns]

# %%
#multi column
data.loc[(1,"female"),'age']
# Out:
# pclass  sex
# 1       female     2.0
#         female    14.0
#         female    15.0
#         female    16.0
#         female    16.0
#                   ...
#         female     NaN
#         female     NaN
#         female     NaN
#         female     NaN
#         female     NaN
# Name: age, Length: 95, dtype: float64

# %%
#to select all columns
data.loc[(1,"female"),:]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         0   2.0      1      2  151.5500        S    C
#        female         1  14.0      1      2  120.0000        S    B
#        female         1  15.0      0      1  211.3375        S    B
#        female         1  16.0      0      1   57.9792        C    B
#        female         1  16.0      0      0   86.5000        S    B
# ...                 ...   ...    ...    ...       ...      ...  ...
#        female         1   NaN      1      0  133.6500        S  NaN
#        female         1   NaN      1      0   82.1708        C  NaN
#        female         1   NaN      1      0   51.8625        S    D
#        female         1   NaN      1      0   52.0000        S    C
#        female         1   NaN      1      0   89.1042        C    C
#
# [95 rows x 7 columns]

# %%
#when you want 2 rows outer indexto be included 
data.loc[(slice(None),slice('female')),:]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         0   2.0      1      2  151.5500        S    C
#        female         1  14.0      1      2  120.0000        S    B
#        female         1  15.0      0      1  211.3375        S    B
#        female         1  16.0      0      1   57.9792        C    B
#        female         1  16.0      0      0   86.5000        S    B
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      female         1   NaN      0      0    7.7333        Q  NaN
#        female         1   NaN      0      0    7.7375        Q  NaN
#        female         0   NaN      8      2   69.5500        S  NaN
#        female         0   NaN      8      2   69.5500        S  NaN
#        female         0   NaN      1      2   23.4500        S  NaN
#
# [315 rows x 7 columns]

# %%
data.plot(subplots=True,figsize=(15,12),sharex=False,sharey=False) 
plt.show()

# %%
data.age.plot(figsize=(12,8)) 
plt.show()

# %%
#styles for plt 
data.age.plot(figsize=(15,12),fontsize=20,c="r",linestyle='-',xlim=(0,900),ylim=(0,80),xticks=xticks,yticks=yticks,rot=90)  
plt.title("Titanic-ages",fontsize=15) 
plt.legend(loc="best",fontsize=13) 
plt.xlabel('Passenge no',fontsize=20) 
plt.ylabel('Age',fontsize=20)
#plt.grid()
plt.show()

# %%
xticks = [x for x in range(0,901, 50)]

# %%
yticks = [y for y in range(0,81, 5)]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %%
data.age.value_counts(bins=10)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: age, dtype: int64

# %%
data.age.plot(kind="hist",figsize=(12,8),fontsize=20,bins=30) 
plt.show()

# %%
#without using plot we can declare hist() 
plt.figure(figsize=(10,8)) 
data.age.hist(bins=80,xlabelsize=15,ylabelsize=15,cumulative=True)
# Out:
# <AxesSubplot:>

# %%
#zero based indexing and negative based indexing 
#using summer dataframe 
summer=pd.read_csv('C:\\Users\\Rohith varma\\Downloads\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\summer.csv')

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
#position based indexing 
# lets say if we want to get the first row in a table then we use iloc operator 

summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
# 3 rows 
summer.iloc[[0,1,2]]
# Out:
#    Year    City     Sport Discipline            Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming      HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming   HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming  DRIVAS, Dimitrios     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze

# %%
summer.iloc[0:3]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred      1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HAJOS, Alfred                  100M Freestyle    Gold
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
summer.iloc[1][2]
# Out:
# 'Aquatics'

# %%
summer.iloc[0, :3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[0, [2,3,4]]
# Out:
# Sport         Aquatics
# Discipline    Swimming
# Country            HUN
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[0:4 ,[1,2,3,5]]
# Out:
#                       City     Sport Discipline Gender
# Athlete
# HAJOS, Alfred       Athens  Aquatics   Swimming    Men
# HERSCHMANN, Otto    Athens  Aquatics   Swimming    Men
# DRIVAS, Dimitrios   Athens  Aquatics   Swimming    Men
# MALOKINIS, Ioannis  Athens  Aquatics   Swimming    Men

# %%
#selecting columns with iloc column 
summer.iloc[: ,4].equals(summer.Country)
# Out:
# True

# %%
summer.iloc[3,4]
# Out:
# 'GRE'

# %%
#label based indexing we use loc[]
summer.loc['PHELPS, Michael']
# Out:
#                  Year    City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004  Athens  Aquatics   Swimming     USA    Men
# ...               ...     ...       ...        ...     ...    ...
# PHELPS, Michael  2012  London  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2012  London  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2012  London  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2012  London  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2012  London  Aquatics   Swimming     USA    Men
#
#                                   Event   Medal
# Athlete
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# ...

# %%
summer.loc['PHELPS, Michael',['Medal','Event']]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# ...                 ...                     ...
# PHELPS, Michael  Silver          200M Butterfly
# PHELPS, Michael    Gold             200M Medley
# PHELPS, Michael  Silver        4X100M Freestyle
# PHELPS, Michael    Gold           4X100M Medley
# PHELPS, Michael    Gold        4X200M Freestyle
#
# [22 rows x 2 columns]

# %%
summer.loc[['PHELPS, Michael','LEWIS, Carl'],['Medal','Event']]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# ...                 ...                     ...
# LEWIS, Carl      Silver                    200M
# LEWIS, Carl        Gold               Long Jump
# LEWIS, Carl        Gold            4X100M Relay
# LEWIS, Carl        Gold               Long Jump
# LEWIS, Carl        Gold               Long Jump
#
# [32 rows x 2 columns]

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.loc[:'CHASAPIS, Spiridon']
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.head(20) 
pd.options.display.max_rows=40

# %%
summer.head(20)
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens   Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
summer.loc['DRIVAS, Dimitrios':'BLAKE, Arthur','City':'Gender']
# Out:
#                          City      Sport Discipline Country Gender
# Athlete
# DRIVAS, Dimitrios      Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          Athens  Athletics  Athletics     USA    Men
# SZOKOLYI, Alajos       Athens  Athletics  Athletics     HUN    Men
# BURKE, Thomas          Athens  Athletics  Athletics     USA    Men
# HOFMANN, Fritz         Athens  Athletics  Athletics     GER    Men
# ...

# %%
print(summer.loc['UNDA, Maider','Event'])
# Out:
# Wf 72 KG

# %%
#reindex will work on missing values but not on duplicte values 
#summer.loc[40000,'Medal'] gives error but using reindex will sole that

summer.reindex(index=[0,5,40000], columns=['Athlete','Medal'])
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 40000                    NaN     NaN

# %%
print(summer['Athlete'].nunique())
# Out:
# 22762

# %%
summer['Athlete'].describe()
# Out:
# count               31165
# unique              22762
# top       PHELPS, Michael
# freq                   22
# Name: Athlete, dtype: object

# %%
summer['Athlete'].value_counts().head(1).index[0]
# Out:
# 'PHELPS, Michael'

# %%
l=pd.Series(['Madrid','Paris'],index=['Spain','France']) 
l
# Out:
# Spain     Madrid
# France     Paris
# dtype: object

# %%
dic={1:10,3:25,2:5,4:45,5:3,6:0,7:None} 
dic
# Out:
# {1: 10, 3: 25, 2: 5, 4: 45, 5: 3, 6: 0, 7: None}

# %%
sales=pd.Series(dic)

# %%
sales
# Out:
# 1    10.0
# 3    25.0
# 2     5.0
# 4    45.0
# 5     3.0
# 6     0.0
# 7     NaN
# dtype: float64

# %%
sales.sort_values(ascending=False,na_position="last",inplace=True)

# %%
sales
# Out:
# 4    45.0
# 3    25.0
# 1    10.0
# 2     5.0
# 5     3.0
# 6     0.0
# 7     NaN
# dtype: float64

# %%
k=summer.columns[0:3].to_list()

# %%
k
# Out:
# ['Year', 'City', 'Sport']

# %%
print('Year','City','Sport')
# Out:
# Year City Sport

# %%
#changing row index labels 
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.reset_index()
# Out:
#                          Athlete  Year    City      Sport  \
# 0                  HAJOS, Alfred  1896  Athens   Aquatics
# 1               HERSCHMANN, Otto  1896  Athens   Aquatics
# 2              DRIVAS, Dimitrios  1896  Athens   Aquatics
# 3             MALOKINIS, Ioannis  1896  Athens   Aquatics
# 4             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                          ...   ...     ...        ...
# 31160         JANIKOWSKI, Damian  2012  London  Wrestling
# 31161  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# 31162             TOTROV, Rustam  2012  London  Wrestling
# 31163          ALEKSANYAN, Artur  2012  London  Wrestling
# 31164             LIDBERG, Jimmy  2012  London  Wrestling
#
#                 Discipline Country Gender                       Event   Medal
# 0                 Swimming     HUN    Men              100M Freestyle    Gold
# 1                 Swimming     AUT    Men              100M Freestyle  Silver
# ...

# %%
summer.set_index('Year')
# Out:
#         City      Sport           Discipline Country Gender  \
# Year
# 1896  Athens   Aquatics             Swimming     HUN    Men
# 1896  Athens   Aquatics             Swimming     AUT    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# 1896  Athens   Aquatics             Swimming     GRE    Men
# ...      ...        ...                  ...     ...    ...
# 2012  London  Wrestling  Wrestling Freestyle     POL    Men
# 2012  London  Wrestling  Wrestling Freestyle     IRI    Men
# 2012  London  Wrestling  Wrestling Freestyle     RUS    Men
# 2012  London  Wrestling  Wrestling Freestyle     ARM    Men
# 2012  London  Wrestling  Wrestling Freestyle     SWE    Men
#
#                            Event   Medal
# Year
# 1896              100M Freestyle    Gold
# 1896              100M Freestyle  Silver
# 1896  100M Freestyle For Sailors  Bronze
# 1896  100M Freestyle For Sailors    Gold
# ...

# %%
summer.reset_index()
# Out:
#                          Athlete  Year    City      Sport  \
# 0                  HAJOS, Alfred  1896  Athens   Aquatics
# 1               HERSCHMANN, Otto  1896  Athens   Aquatics
# 2              DRIVAS, Dimitrios  1896  Athens   Aquatics
# 3             MALOKINIS, Ioannis  1896  Athens   Aquatics
# 4             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                          ...   ...     ...        ...
# 31160         JANIKOWSKI, Damian  2012  London  Wrestling
# 31161  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# 31162             TOTROV, Rustam  2012  London  Wrestling
# 31163          ALEKSANYAN, Artur  2012  London  Wrestling
# 31164             LIDBERG, Jimmy  2012  London  Wrestling
#
#                 Discipline Country Gender                       Event   Medal
# 0                 Swimming     HUN    Men              100M Freestyle    Gold
# 1                 Swimming     AUT    Men              100M Freestyle  Silver
# ...

# %%
#Renaming index and column labels 
#if you want to rename a passenger name 
summer.rename(mapper={'MALOKINIS, Ioannis':'NALOKINIS, Ioannis'},axis="index") #row index names
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# NALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
#to change column names 
summer.rename(columns={"Sex":'Gender',"city":'Host_city'}) #column index names
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.index.name='place' #when you want to change the index name

# %%
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# place
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# place
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
#Advanced filtering with between(), isin() and ~ 
og_1988=summer.loc[summer.Year==1988]

# %%
og_since1992=summer.loc[summer.Year>=1992]

# %%
og_60s=summer.loc[summer.Year.between(1960,1969,inclusive=True)]

# %%
og_60s
# Out:
#                              Year    City      Sport       Discipline Country  \
# place
# PHELPS, Brian Eric           1960    Rome   Aquatics           Diving     GBR
# WEBSTER, Robert David        1960    Rome   Aquatics           Diving     USA
# TOBIAN, Gary Milburn         1960    Rome   Aquatics           Diving     USA
# KRUTOVA, Ninel               1960    Rome   Aquatics           Diving     URS
# KRÄMER-ENGEL-GULBIN, Ingrid  1960    Rome   Aquatics           Diving     EUA
# ...                           ...     ...        ...              ...     ...
# METZ, Lothar                 1968  Mexico  Wrestling  Wrestling Gre-R     GDR
# OLEINIK, Valentin            1968  Mexico  Wrestling  Wrestling Gre-R     URS
# MARTINESCU, Nicolae          1968  Mexico  Wrestling  Wrestling Gre-R     ROU
# RADEV, Boyan Aleksandrov     1968  Mexico  Wrestling  Wrestling Gre-R     BUL
# YAKOVENKO, Nikolai           1968  Mexico  Wrestling  Wrestling Gre-R     URS
#
# ...

# %%
summer.drop(columns=['Sport','Discipline'],inplace=True)

# %%
summer.head(3)
# Out:
#    Year    City            Athlete Country Gender                       Event  \
# 0  1896  Athens      HAJOS, Alfred     HUN    Men              100M Freestyle
# 1  1896  Athens   HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2  1896  Athens  DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
#
#     Medal
# 0    Gold
# 1  Silver
# 2  Bronze

# %%
#remove rows 
summer.drop(index=['HAJOS, Alfred','HERSCHMANN, Otto'],inplace=True)

# %%
summer.head(5)
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
#new dataset sales.csv

sales=pd.read_csv('C:\\Users\\Rohith varma\\Downloads\\Course_Materials_Part1\\Course_Materials_Part1\\Video_Lecture_NBs\\sales.csv',index_col=0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.min(axis=0)
# Out:
# Mon    17.0
# Tue     9.0
# Wed    15.0
# Thu     8.0
# Fri     7.0
# dtype: float64

# %%
#to define a range we will be using built in method 
def range(series):
    return series.max() - series.min()

# %%
sales.apply(range,axis=1)
# Out:
# Steven    19.0
# Mike      78.0
# Andi      46.0
# Paul      80.0
# dtype: float64

# %%
#applying lambda 
sales.apply(lambda series:series.max() - series.min(),axis=0)
#instead of apply we can also use map method 
sales.ANYCOLUMN.map(lambda...)
# Out:
# Mon    70.0
# Tue    58.0
# Wed    59.0
# Thu    79.0
# Fri    26.0
# dtype: float64

# %%
sales.applymap(lambda x:0.4*x-5)
# Out:
#          Mon   Tue   Wed   Thu  Fri
# Steven   8.6   5.8   1.0   NaN  8.2
# Mike    13.0  -1.4  24.6  29.8 -0.2
# Andi     1.8   8.2  16.6  -1.8  6.6
# Paul    29.8  21.8   5.8  13.0 -2.2

# %%
hello="Hello World"
hello.lower()
# Out:
# 'hello world'

# %%
hello.split(" ")
# Out:
# ['Hello', 'World']

# %%
hello.replace("he",'hi')
# Out:
# 'Hello World'

# %%
hello
# Out:
# 'Hello World'

# %%
names=summer.loc[:9, 'Athlete'].copy()

# %%
names
# Out:
# 0            HAJOS, Alfred
# 1         HERSCHMANN, Otto
# 2        DRIVAS, Dimitrios
# 3       MALOKINIS, Ioannis
# 4       CHASAPIS, Spiridon
# 5    CHOROPHAS, Efstathios
# 6            HAJOS, Alfred
# 7         ANDREOU, Joannis
# 8    CHOROPHAS, Efstathios
# 9            NEUMANN, Paul
# Name: Athlete, dtype: object

# %%
names.dtypes
# Out:
# dtype('O')

# %%
#cant do just lower on string but str.lower()
names.str.lower()
# Out:
# 0            hajos, alfred
# 1         herschmann, otto
# 2        drivas, dimitrios
# 3       malokinis, ioannis
# 4       chasapis, spiridon
# 5    chorophas, efstathios
# 6            hajos, alfred
# 7         andreou, joannis
# 8    chorophas, efstathios
# 9            neumann, paul
# Name: Athlete, dtype: object

# %%
summer.Event.str.split(' ',n=2,expand=True)#1  st whitespace , expand=True split to columns
# Out:
#           0          1            2
# 0      100M  Freestyle         None
# 1      100M  Freestyle         None
# 2      100M  Freestyle  For Sailors
# 3      100M  Freestyle  For Sailors
# 4      100M  Freestyle  For Sailors
# ...     ...        ...          ...
# 31160    Wg         84           KG
# 31161    Wg         96           KG
# 31162    Wg         96           KG
# 31163    Wg         96           KG
# 31164    Wg         96           KG
#
# [31165 rows x 3 columns]

# %%
#str.contains 
summer[summer.Event.str.contains('100M')]
# Out:
#        Year    City      Sport Discipline               Athlete Country  \
# 0      1896  Athens   Aquatics   Swimming         HAJOS, Alfred     HUN
# 1      1896  Athens   Aquatics   Swimming      HERSCHMANN, Otto     AUT
# 2      1896  Athens   Aquatics   Swimming     DRIVAS, Dimitrios     GRE
# 3      1896  Athens   Aquatics   Swimming    MALOKINIS, Ioannis     GRE
# 4      1896  Athens   Aquatics   Swimming    CHASAPIS, Spiridon     GRE
# ...     ...     ...        ...        ...                   ...     ...
# 29660  2012  London  Athletics  Athletics       STEWART, Kerron     JAM
# 29661  2012  London  Athletics  Athletics  BRYZGINA, Yelyzaveta     UKR
# 29662  2012  London  Athletics  Athletics          POVH, Olesya     UKR
# 29663  2012  London  Athletics  Athletics       RYEMYEN, Mariya     UKR
# 29664  2012  London  Athletics  Athletics        STUY, Hrystyna     UKR
#
#       Gender                       Event   Medal
# 0        Men              100M Freestyle    Gold
# ...
